# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedDanishKhurram/Assignments/blob/main/pandas_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Mountain' : ['Mount Everest/ Sagarmatha/Chomolungma','K2/ Qogir','Kangchenjunga',
                  'Lhostse' , 'Makalu' , 'Cho_oyu' , 'DhaulagiriI' , 'Manaslu' , 'NangaParbat' , 'Annapurna'],
    'Heights' : ['8848','8611','8586','8516','8485','8188','8167','8163','8126','8091'],
    'Range' :['Mahalangur','baltoro karakoram','Kangchenjunga','Mahanlangur Himalaya',
              'Mahalangur Himalaya','Mahalangur Himalaya','Dhaulagiri Himalaya','Manaslu Himalaya','Nanga Parbat','Annapurna Himalaya'],
    'Coordinates': ["27°59'17''N", "27°59'17''N", "27°59'17''N", "27°59'17''N", "27°59'17''N",
                    "27°59'17''N", "27°59'17''N", "27°59'17''N", "27°59'17''N","27°59'17''N"],
    'Parent mountain':['Nan','Mount Everest','Mount Everest','Mount Everest','Mount Everest','Mount Everest','K2','Cho_oyu','Dhaulagiri','cho Oyu'],
    'first ascent' :['1953','1954','1955','1956','1955','1954','1960','1956','1953','1950'],
    'Ascent bef 2004' :['>>145','45','38','26','45','79','51','49','52','36'],
    'Failed attempt bef 2004':['121.0','44.0','24.0','26.0','52.0','28.0','39.0','45.0','67.0','47.0']
}
df = pd.DataFrame(data)
df

#column
mountain = df['Mountain']
print("For a column:")
print(mountain)

#multiple columns
subset = df[['Mountain', 'Heights']]
print("For multiple columns:")
print(subset)
#rows
print("For Row")
row = df.loc[2]
row
df
# Out:
# For a column:
# 0    Mount Everest/ Sagarmatha/Chomolungma
# 1                                K2/ Qogir
# 2                            Kangchenjunga
# 3                                  Lhostse
# 4                                   Makalu
# 5                                  Cho_oyu
# 6                              DhaulagiriI
# 7                                  Manaslu
# 8                              NangaParbat
# 9                                Annapurna
# Name: Mountain, dtype: object
# For multiple columns:
#                                 Mountain Heights
# 0  Mount Everest/ Sagarmatha/Chomolungma    8848
# 1                              K2/ Qogir    8611
# 2                          Kangchenjunga    8586
# 3                                Lhostse    8516
# 4                                 Makalu    8485
# 5                                Cho_oyu    8188
# 6                            DhaulagiriI    8167
# 7                                Manaslu    8163
# ...

# %%
#this is used to
df.head()
# Out:
#                                 Mountain Heights                 Range  \
# 0  Mount Everest/ Sagarmatha/Chomolungma    8848            Mahalangur
# 1                              K2/ Qogir    8611     baltoro karakoram
# 2                          Kangchenjunga    8586         Kangchenjunga
# 3                                Lhostse    8516  Mahanlangur Himalaya
# 4                                 Makalu    8485   Mahalangur Himalaya
#
#    Coordinates Parent mountain first ascent Ascent bef 2004  \
# 0  27°59'17''N             Nan         1953           >>145
# 1  27°59'17''N   Mount Everest         1954              45
# 2  27°59'17''N   Mount Everest         1955              38
# 3  27°59'17''N   Mount Everest         1956              26
# 4  27°59'17''N   Mount Everest         1955              45
#
#   Failed attempt bef 2004
# 0                   121.0
# 1                    44.0
# 2                    24.0
# 3                    26.0
# 4                    52.0

# %%
#this is used for the last 5 data
df.tail()
# Out:
#       Mountain Heights                Range  Coordinates Parent mountain  \
# 5      Cho_oyu    8188  Mahalangur Himalaya  27°59'17''N   Mount Everest
# 6  DhaulagiriI    8167  Dhaulagiri Himalaya  27°59'17''N              K2
# 7      Manaslu    8163     Manaslu Himalaya  27°59'17''N         Cho_oyu
# 8  NangaParbat    8126         Nanga Parbat  27°59'17''N      Dhaulagiri
# 9    Annapurna    8091   Annapurna Himalaya  27°59'17''N         cho Oyu
#
#   first ascent Ascent bef 2004 Failed attempt bef 2004
# 5         1954              79                    28.0
# 6         1960              51                    39.0
# 7         1956              49                    45.0
# 8         1953              52                    67.0
# 9         1950              36                    47.0

# %%
#this is used to discribe the data
df.describe()
# Out:
#                                      Mountain Heights                Range  \
# count                                      10      10                   10
# unique                                     10      10                    9
# top     Mount Everest/ Sagarmatha/Chomolungma    8848  Mahalangur Himalaya
# freq                                        1       1                    2
#
#         Coordinates Parent mountain first ascent Ascent bef 2004  \
# count            10              10           10              10
# unique            1               6            6               9
# top     27°59'17''N   Mount Everest         1953              45
# freq             10               5            2               2
#
#        Failed attempt bef 2004
# count                       10
# unique                      10
# top                      121.0
# freq                         1

# %%
#this is used to know if there is any null number
df.isnull().sum()
# Out:
# Mountain                   0
# Heights                    0
# Range                      0
# Coordinates                0
# Parent mountain            0
# first ascent               0
# Ascent bef 2004            0
# Failed attempt bef 2004    0
# dtype: int64

# %%
#it is used to see the specific columns

df['Range']
# Out:
# 0              Mahalangur
# 1       baltoro karakoram
# 2           Kangchenjunga
# 3    Mahanlangur Himalaya
# 4     Mahalangur Himalaya
# 5     Mahalangur Himalaya
# 6     Dhaulagiri Himalaya
# 7        Manaslu Himalaya
# 8            Nanga Parbat
# 9      Annapurna Himalaya
# Name: Range, dtype: object

# %%
# Out:
#                                 Mountain Heights                 Range  \
# 0  Mount Everest/ Sagarmatha/Chomolungma    8848            Mahalangur
# 1                              K2/ Qogir    8611     baltoro karakoram
# 2                          Kangchenjunga    8586         Kangchenjunga
# 3                                Lhostse    8516  Mahanlangur Himalaya
# 4                                 Makalu    8485   Mahalangur Himalaya
# 5                                Cho_oyu    8188   Mahalangur Himalaya
# 6                            DhaulagiriI    8167   Dhaulagiri Himalaya
# 7                                Manaslu    8163      Manaslu Himalaya
# 8                            NangaParbat    8126          Nanga Parbat
# 9                              Annapurna    8091    Annapurna Himalaya
#
#    Coordinates Parent mountain first ascent Ascent bef 2004  \
# 0  27°59'17''N             Nan         1953           >>145
# 1  27°59'17''N   Mount Everest         1954              45
# ...
